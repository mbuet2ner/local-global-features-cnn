# %% [markdown]
# # ImageNette bounding boxes data

# %% [markdown]
# Since ImageNet is quite big with over 150GB of image data, we use a much smaller variant called [imagenette](https://github.com/fastai/imagenette) that was created by Jeremy Howard from [fast.ai](https://docs.fast.ai/).
#
# Imagenette is
# > a subset of 10 easily classified classes from Imagenet:
# >
# > (tench, English springer, cassette player, chain saw, church, French horn, garbage truck, gas pump, golf ball, parachute).
#
# For this notebook we use the full scaled version of the images available from [here](https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz).
#
# This is the new version from **Dec 6 2019**, that uses a 70/30 train/validate split!

# %% [markdown]
# _______

# %% [markdown]
# ## Create dataset

# %% [markdown]
# First let's read in the `pd.DataFrame` we created with our `1_imagenet_boundingboxes.ipynb` notebook

# %%
import tarfile
import pandas as pd
import urllib.request

from pathlib import Path

# %% [markdown]
# We can directly use the `.pkl` file we created earlier

# %%
save_path = Path("data/")

# %%
complete_data = pd.read_pickle(save_path / "imagenet_boundingboxes.pkl")

# %% [markdown]
# Let's have a look

# %%
complete_data[:5]
# Out:
#            filename     folder object  object.bndbox.xmax object.bndbox.xmin  \
# 0    n07683490_6960  n07683490    NaN               290.0                 78
# 0    n07683490_5743  n07683490    NaN               474.0                273
# 0    n07683490_7315  n07683490    NaN               483.0                141
# 0    n07683490_6158  n07683490    NaN               365.0                 93
# 0    n07683490_7703  n07683490    NaN               355.0                134
# ..              ...        ...    ...                 ...                ...
# 0   n03594734_38401  n03594734    NaN               460.0                 41
# 0   n03594734_37947  n03594734    NaN               373.0                  0
# 0   n03594734_29003  n03594734    NaN               316.0                 34
# 0   n03594734_36264  n03594734    NaN               326.0                 51
# 0   n03594734_45362  n03594734    NaN               433.0                 35
#
#    object.bndbox.ymax object.bndbox.ymin object.difficult object.name  \
# 0                 307                 91                0   n07683490
# 0                 399                 56                0   n07683490
# 0                 301                  0                0   n07683490
# 0                 311                 77                0   n07683490
# 0                 299                 80                0   n07683490
# ..                ...                ...              ...         ...
# 0                 347                  0                0   n03594734
# 0                 447                 67                0   n03594734
# 0                 226                 16                0   n03594734
# 0                 481                  8                0   n03594734
# 0                 331                  6                0   n03594734
#
#     object.pose object.truncated segmented size.depth size.height size.width  \
# 0   Unspecified                0         0          3         375        500
# 0   Unspecified                0         0          3         480        480
# 0   Unspecified                0         0          3         374        500
# 0   Unspecified                0         0          3         374        500
# 0   Unspecified                0         0          3         375        500
# ..          ...              ...       ...        ...         ...        ...
# 0   Unspecified                0         0          3         375        500
# 0   Unspecified                0         0          3         500        375
# 0   Unspecified                0         0          3         227        329
# 0   Unspecified                0         0          3         500        375
# 0   Unspecified                0         0          3         339        500
#
#       source.database
# 0   ImageNet database
# 0   ImageNet database
# 0   ImageNet database
# 0   ImageNet database
# 0   ImageNet database
# ..                ...
# 0   ImageNet database
# 0   ImageNet database
# 0   ImageNet database
# 0   ImageNet database
# 0   ImageNet database
#
# [1073739 rows x 16 columns]

# %% [markdown]
# The index looks odd. Since we simply merged the dataset, every row has a `1`. Let's fix that

# %%
complete_data.reset_index(drop=True, inplace=True)
complete_data[:5]
# Out:
#                 filename     folder object  object.bndbox.xmax  \
# 0         n07683490_6960  n07683490    NaN               290.0
# 1         n07683490_5743  n07683490    NaN               474.0
# 2         n07683490_7315  n07683490    NaN               483.0
# 3         n07683490_6158  n07683490    NaN               365.0
# 4         n07683490_7703  n07683490    NaN               355.0
# ...                  ...        ...    ...                 ...
# 1073734  n03594734_38401  n03594734    NaN               460.0
# 1073735  n03594734_37947  n03594734    NaN               373.0
# 1073736  n03594734_29003  n03594734    NaN               316.0
# 1073737  n03594734_36264  n03594734    NaN               326.0
# 1073738  n03594734_45362  n03594734    NaN               433.0
#
#         object.bndbox.xmin object.bndbox.ymax object.bndbox.ymin  \
# 0                       78                307                 91
# 1                      273                399                 56
# 2                      141                301                  0
# 3                       93                311                 77
# 4                      134                299                 80
# ...                    ...                ...                ...
# 1073734                 41                347                  0
# 1073735                  0                447                 67
# 1073736                 34                226                 16
# 1073737                 51                481                  8
# 1073738                 35                331                  6
#
#         object.difficult object.name  object.pose object.truncated segmented  \
# 0                      0   n07683490  Unspecified                0         0
# 1                      0   n07683490  Unspecified                0         0
# 2                      0   n07683490  Unspecified                0         0
# 3                      0   n07683490  Unspecified                0         0
# 4                      0   n07683490  Unspecified                0         0
# ...                  ...         ...          ...              ...       ...
# 1073734                0   n03594734  Unspecified                0         0
# 1073735                0   n03594734  Unspecified                0         0
# 1073736                0   n03594734  Unspecified                0         0
# 1073737                0   n03594734  Unspecified                0         0
# 1073738                0   n03594734  Unspecified                0         0
#
#         size.depth size.height size.width    source.database
# 0                3         375        500  ImageNet database
# 1                3         480        480  ImageNet database
# 2                3         374        500  ImageNet database
# 3                3         374        500  ImageNet database
# 4                3         375        500  ImageNet database
# ...            ...         ...        ...                ...
# 1073734          3         375        500  ImageNet database
# 1073735          3         500        375  ImageNet database
# 1073736          3         227        329  ImageNet database
# 1073737          3         500        375  ImageNet database
# 1073738          3         339        500  ImageNet database
#
# [1073739 rows x 16 columns]

# %% [markdown]
# A closer look at the data with some basic statistics
#
# **Note**: May take a while

# %%
complete_data.describe(include='all')

# %% [markdown]
# ### Get subset of classes used in imagenette
# For the smaller imagenette we don't have to rely on all the images present in ImageNet
#
# **Note**: We do not follow the imagenette train/test split here, but the ImageNet partitioning

# %% [markdown]
# #### **Note**: If you are using a GNU/Linux based operating system (e.g. `Google Colab`) use this faster variant:

# %%
! wget -c https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz -P data/
# Out:
# --2020-06-20 14:04:48--  https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz
# Auflösen des Hostnamens s3.amazonaws.com (s3.amazonaws.com)… 52.216.97.221
# Verbindungsaufbau zu s3.amazonaws.com (s3.amazonaws.com)|52.216.97.221|:443 … verbunden.
# HTTP-Anforderung gesendet, auf Antwort wird gewartet … 200 OK
# Länge: 1556914727 (1,4G) [application/x-tar]
# Wird in »data/imagenette2.tgz« gespeichert.
#
# imagenette2.tgz     100%[===================>]   1,45G  6,37MB/s    in 13m 0s
#
# 2020-06-20 14:17:49 (1,90 MB/s) - »data/imagenette2.tgz« gespeichert [1556914727/1556914727]

# %%
! tar -zxf data/imagenette2.tgz -C data/

# %% [markdown]
# #### **Note**: If you are using Windows, use the following code. Unpacking takes a while...

# %%
imagenette_file = "https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz"
ftpstream = urllib.request.urlopen(imagenette_file)
imagenette_file = tarfile.open(fileobj=ftpstream, mode="r|gz")
imagenette_file.extractall(path=save_path)

# %% [markdown]
# Create imagenette `Path` object

# %%
imagenette_path = save_path / "imagenette2"

# %%
# for now we filter out those that would be in the original ImageNet validation set
imgn_pict = [filename for filename in imagenette_path.rglob('*.JPEG') if '_val_' not in filename.name]

print(imgn_pict[:10])
print(f'\nTotal images: {len(imgn_pict)}')
# Out:
# [PosixPath('data/imagenette2/train/n03394916/n03394916_23108.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_59626.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_5529.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_36154.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_32997.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_61934.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_59745.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_21289.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_29164.JPEG'), PosixPath('data/imagenette2/train/n03394916/n03394916_7547.JPEG')]
#
# Total images: 12894

# %% [markdown]
# For now we only need the filename without the `.JPEG` ending to check against our database

# %%
imgn_pict_str = [filename.name.split(".")[0] for filename in imgn_pict]
imgn_pict_str[:10]
# Out:
# ['n03394916_23108',
#  'n03394916_59626',
#  'n03394916_5529',
#  'n03394916_36154',
#  'n03394916_32997',
#  'n03394916_61934',
#  'n03394916_59745',
#  'n03394916_21289',
#  'n03394916_29164',
#  'n03394916_7547']

# %%
print(len(imgn_pict_str))
# Out:
# 12894

# %% [markdown]
# We only need those that are present in imagenette

# %%
complete_data = pd.read_pickle(save_path / "imagenet_boundingboxes.pkl")

# %%
imgn_data = complete_data.loc[complete_data['filename'].isin(imgn_pict_str)]
imgn_data[:5]
# Out:
#       folder         filename segmented    source.database size.width  \
# 0  n03445777   n03445777_5901         0  ImageNet database        500
# 0  n03445777   n03445777_8145         0  ImageNet database        500
# 0  n03445777   n03445777_3928         0  ImageNet database        500
# 0  n03445777  n03445777_10304         0  ImageNet database        500
# 0  n03445777   n03445777_9971         0  ImageNet database        500
#
#   size.height size.depth object.name  object.pose object.truncated  \
# 0         334          3   n03445777  Unspecified                0
# 0         375          3   n03445777  Unspecified                0
# 0         333          3   n03445777  Unspecified                0
# 0         375          3   n03445777  Unspecified                0
# 0         375          3   n03445777  Unspecified                0
#
#   object.difficult object.bndbox.xmin object.bndbox.ymin object.bndbox.xmax  \
# 0                0                249                112                455
# 0                0                 79                127                294
# 0                0                131                148                238
# 0                0                 64                  0                341
# 0                0                 95                 41                379
#
#   object.bndbox.ymax object
# 0                303    NaN
# 0                339    NaN
# 0                256    NaN
# 0                265    NaN
# 0                330    NaN

# %% [markdown]
# Also, let us drop filter `NAaNs` in the bounding box columns

# %%
imgn_data_flt = imgn_data[imgn_data[['object.bndbox.xmax', 'object.bndbox.xmin', 'object.bndbox.ymin', 'size.height', 'size.width']].notnull().all(1)]
len(imgn_data_flt)
# Out:
# 4312

# %% [markdown]
# Fix the index again, since we dropped columns

# %%
imgn_data_flt.reset_index(drop=True,inplace=True)
imgn_data_flt[:5]
# Out:
#       folder         filename segmented    source.database size.width  \
# 0  n03445777   n03445777_5901         0  ImageNet database        500
# 1  n03445777   n03445777_8145         0  ImageNet database        500
# 2  n03445777   n03445777_3928         0  ImageNet database        500
# 3  n03445777  n03445777_10304         0  ImageNet database        500
# 4  n03445777   n03445777_9971         0  ImageNet database        500
#
#   size.height size.depth object.name  object.pose object.truncated  \
# 0         334          3   n03445777  Unspecified                0
# 1         375          3   n03445777  Unspecified                0
# 2         333          3   n03445777  Unspecified                0
# 3         375          3   n03445777  Unspecified                0
# 4         375          3   n03445777  Unspecified                0
#
#   object.difficult object.bndbox.xmin object.bndbox.ymin object.bndbox.xmax  \
# 0                0                249                112                455
# 1                0                 79                127                294
# 2                0                131                148                238
# 3                0                 64                  0                341
# 4                0                 95                 41                379
#
#   object.bndbox.ymax object
# 0                303    NaN
# 1                339    NaN
# 2                256    NaN
# 3                265    NaN
# 4                330    NaN

# %% [markdown]
# #### Save data to disk

# %% [markdown]
# Write the `DataFrame` to a `.csv` file

# %%
imgn_data_flt.to_csv(save_path / "imagenette_boundingboxes.csv", encoding='utf-8', index=False)

# %% [markdown]
# Write the `DataFrame` to a `.pkl` file

# %%
imgn_data_flt.to_pickle(save_path / "imagenette_boundingboxes.pkl")

# %% [markdown]
# We could also use the `feather` format...
